# %%
#pip install s3fs

# %%
from kafka import KafkaConsumer
from time import sleep
from json import dumps,loads
import json
from s3fs import S3FileSystem

# %%
consumer = KafkaConsumer(
    'demo_test',
     bootstrap_servers=['3.110.219.34:9092'], #add your IP here
    value_deserializer=lambda x: loads(x.decode('utf-8')))

# %%
for c in consumer:
     print(c.value)
# Out:
# {'Index': 'HSI', 'Date': '1992-04-06', 'Open': 4911.200195, 'High': 4912.0, 'Low': 4859.399902, 'Close': 4896.899902, 'Adj Close': 4896.899902, 'Volume': 0.0, 'CloseUSD': 636.59698726}
# {'Index': 'GSPTSE', 'Date': '1986-01-10', 'Open': 2831.300049, 'High': 2833.600098, 'Low': 2817.600098, 'Close': 2817.600098, 'Adj Close': 2810.445068, 'Volume': 17600000.0, 'CloseUSD': 2338.60808134}
# {'Index': 'GSPTSE', 'Date': '1999-10-08', 'Open': 7043.600098, 'High': 7116.0, 'Low': 7043.600098, 'Close': 7116.0, 'Adj Close': 7116.0, 'Volume': 6092140000.0, 'CloseUSD': 5906.28}
# {'Index': 'IXIC', 'Date': '2013-07-29', 'Open': 3604.290039, 'High': 3618.860107, 'Low': 3592.800049, 'Close': 3599.139893, 'Adj Close': 3599.139893, 'Volume': 1545720000.0, 'CloseUSD': 3599.139893}
# {'Index': 'IXIC', 'Date': '1988-07-28', 'Open': 382.399994, 'High': 384.100006, 'Low': 382.100006, 'Close': 384.100006, 'Adj Close': 384.100006, 'Volume': 116260000.0, 'CloseUSD': 384.100006}
# {'Index': 'GDAXI', 'Date': '2019-09-06', 'Open': 12146.0, 'High': 12205.09961, 'Low': 12131.29004, 'Close': 12191.73047, 'Adj Close': 12191.73047, 'Volume': 80411000.0, 'CloseUSD': 14873.9111734}
# {'Index': 'N225', 'Date': '1976-07-09', 'Open': 4839.0, 'High': 4839.0, 'Low': 4839.0, 'Close': 4839.0, 'Adj Close': 4839.0, 'Volume': 0.0, 'CloseUSD': 48.39}
# {'Index': 'NYA', 'Date': '1996-05-01', 'Open': 3716.97998, 'High': 3716.97998, 'Low': 3716.97998, 'Close': 3716.97998, 'Adj Close': 3716.97998, 'Volume': 0.0, 'CloseUSD': 3716.97998}
# {'Index': 'NYA', 'Date': '2005-10-12', 'Open': 7380.799805, 'High': 7400.830078, 'Low': 7299.060059, 'Close': 7322.740234, 'Adj Close': 7322.740234, 'Volume': 2491280000.0, 'CloseUSD': 7322.740234}
# {'Index': 'N100', 'Date': '2010-11-10', 'Open': 704.289978, 'High': 706.690002, 'Low': 697.460022, 'Close': 700.5, 'Adj Close': 700.5, 'Volume': 366961900.0, 'CloseUSD': 854.61}
# {'Index': 'NYA', 'Date': '1976-12-29', 'Open': 605.659973, 'High': 605.659973, 'Low': 605.659973, 'Close': 605.659973, 'Adj Close': 605.659973, 'Volume': 0.0, 'CloseUSD': 605.659973}
# {'Index': 'IXIC', 'Date': '2004-04-27', 'Open': 2040.530029, 'High': 2053.570068, 'Low': 2027.640015, 'Close': 2032.530029, 'Adj Close': 2032.530029, 'Volume': 1971610000.0, 'CloseUSD': 2032.530029}
# {'Index': 'GSPTSE', 'Date': '2003-02-04', 'Open': 6559.299805, 'High': 6593.700195, 'Low': 6520.200195, 'Close': 6544.899902, 'Adj Close': 6544.899902, 'Volume': 12527630000.0, 'CloseUSD': 5432.26691866}
# {'Index': 'N225', 'Date': '1991-09-06', 'Open': 22492.92969, 'High': 22998.91016, 'Low': 22489.4707, 'Close': 22692.59961, 'Adj Close': 22692.59961, 'Volume': 0.0, 'CloseUSD': 226.9259961}
# {'Index': '399001.SZ', 'Date': '2005-01-13', 'Open': 3063.389893, 'High': 3081.870117, 'Low': 3055.23999, 'Close': 3074.370117, 'Adj Close': 3074.335449, 'Volume': 9800.0, 'CloseUSD': 491.89921872}
# {'Index': 'GSPTSE', 'Date': '2014-08-12', 'Open': 15261.59961, 'High': 15319.90039, 'Low': 15229.7002, 'Close': 15274.2002, 'Adj Close': 15274.2002, 'Volume': 15316930000.0, 'CloseUSD': 12677.586166}
# {'Index': 'N225', 'Date': '1998-09-04', 'Open': 14158.33984, 'High': 14185.86035, 'Low': 14042.91016, 'Close': 14042.91016, 'Adj Close': 14042.91016, 'Volume': 0.0, 'CloseUSD': 140.4291016}
# {'Index': 'N225', 'Date': '2000-03-29', 'Open': 20406.56055, 'High': 20809.17969, 'Low': 20406.56055, 'Close': 20706.65039, 'Adj Close': 20706.65039, 'Volume': 0.0, 'CloseUSD': 207.0665039}
# {'Index': 'SSMI', 'Date': '2014-08-15', 'Open': 8460.429688, 'High': 8483.509766, 'Low': 8366.730469, 'Close': 8366.730469, 'Adj Close': 8366.730469, 'Volume': 47221200.0, 'CloseUSD': 9287.07082059}
# {'Index': 'NYA', 'Date': '1975-06-17', 'Open': 510.390015, 'High': 510.390015, 'Low': 510.390015, 'Close': 510.390015, 'Adj Close': 510.390015, 'Volume': 0.0, 'CloseUSD': 510.390015}
# {'Index': '399001.SZ', 'Date': '2006-09-28', 'Open': 4244.660156, 'High': 4302.22998, 'Low': 4235.279785, 'Close': 4288.370117, 'Adj Close': 4288.321777, 'Volume': 25600.0, 'CloseUSD': 686.13921872}
# {'Index': 'N225', 'Date': '1972-11-21', 'Open': 4618.27002, 'High': 4618.27002, 'Low': 4618.27002, 'Close': 4618.27002, 'Adj Close': 4618.27002, 'Volume': 0.0, 'CloseUSD': 46.1827002}
# {'Index': 'NYA', 'Date': '1967-09-22', 'Open': 569.400024, 'High': 569.400024, 'Low': 569.400024, 'Close': 569.400024, 'Adj Close': 569.400024, 'Volume': 0.0, 'CloseUSD': 569.400024}
# {'Index': 'N225', 'Date': '1970-03-04', 'Open': 2422.72998, 'High': 2422.72998, 'Low': 2422.72998, 'Close': 2422.72998, 'Adj Close': 2422.72998, 'Volume': 0.0, 'CloseUSD': 24.2272998}
# {'Index': 'N225', 'Date': '1998-03-18', 'Open': 17011.89063, 'High': 17022.2793, 'Low': 16500.09961, 'Close': 16619.67969, 'Adj Close': 16619.67969, 'Volume': 0.0, 'CloseUSD': 166.1967969}
# {'Index': 'N225', 'Date': '1971-07-16', 'Open': 2670.879883, 'High': 2670.879883, 'Low': 2670.879883, 'Close': 2670.879883, 'Adj Close': 2670.879883, 'Volume': 0.0, 'CloseUSD': 26.708798830000003}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 for c in consumer:
#       2      print(c.value)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\kafka\consumer\group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\kafka\consumer\group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\kafka\consumer\group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\kafka\consumer\group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\kafka\consumer\group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\kafka\client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\kafka\client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\selectors.py:324, in SelectSelector.select(self, timeout)
#     322 ready = []
#     323 try:
# --> 324     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     325 except InterruptedError:
#     326     return ready
#
# File ~\AppData\Local\Programs\Python\Python310\lib\selectors.py:315, in SelectSelector._select(self, r, w, _, timeout)
#     314 def _select(self, r, w, _, timeout=None):
# --> 315     r, w, x = select.select(r, w, w, timeout)
#     316     return r, w + x, []
#
# KeyboardInterrupt:

# %%
s3 = S3FileSystem()

# %%
for count, i in enumerate(consumer):
    with s3.open("s3://demo-sanu/stock_market_{}.json".format(count), 'w') as file:
        json.dump(i.value, file)
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
#       1 for count, i in enumerate(consumer):
# ----> 2     with s3.open("s3://demo-sanu/stock_market_{}.json".format(count), 'w') as file:
#       3         json.dump(i.value, file)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\fsspec\spec.py:1876, in AbstractBufferedFile.close(self)
#    1874 else:
#    1875     if not self.forced:
# -> 1876         self.flush(force=True)
#    1878     if self.fs is not None:
#    1879         self.fs.invalidate_cache(self.path)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\fsspec\spec.py:1747, in AbstractBufferedFile.flush(self, force)
#    1744         self.closed = True
#    1745         raise
# -> 1747 if self._upload_chunk(final=force) is not False:
#    1748     self.offset += self.buffer.seek(0, 2)
#    1749     self.buffer = io.BytesIO()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\s3fs\core.py:2250, in S3File._upload_chunk(self, final)
#    2247     self.parts.append({"PartNumber": part, "ETag": out["ETag"]})
#    2249 if self.autocommit and final:
# -> 2250     self.commit()
#    2251 return not final
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\s3fs\core.py:2265, in S3File.commit(self)
#    2263     self.buffer.seek(0)
#    2264     data = self.buffer.read()
# -> 2265     write_result = self._call_s3(
#    2266         "put_object",
#    2267         Key=self.key,
#    2268         Bucket=self.bucket,
#    2269         Body=data,
#    2270         ACL=self.acl,
#    2271         **self.kwargs,
#    2272     )
#    2273 else:
#    2274     raise RuntimeError
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\s3fs\core.py:2117, in S3File._call_s3(self, method, *kwarglist, **kwargs)
#    2116 def _call_s3(self, method, *kwarglist, **kwargs):
# -> 2117     return self.fs.call_s3(method, self.s3_additional_kwargs, *kwarglist, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\fsspec\asyn.py:121, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     118 @functools.wraps(func)
#     119 def wrapper(*args, **kwargs):
#     120     self = obj or args[0]
# --> 121     return sync(self.loop, func, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\fsspec\asyn.py:106, in sync(loop, func, timeout, *args, **kwargs)
#     104     raise FSTimeoutError from return_result
#     105 elif isinstance(return_result, BaseException):
# --> 106     raise return_result
#     107 else:
#     108     return return_result
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\fsspec\asyn.py:61, in _runner(event, coro, result, timeout)
#      59     coro = asyncio.wait_for(coro, timeout=timeout)
#      60 try:
# ---> 61     result[0] = await coro
#      62 except Exception as ex:
#      63     result[0] = ex
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\s3fs\core.py:348, in S3FileSystem._call_s3(self, method, *akwarglist, **kwargs)
#     346 logger.debug("CALL: %s - %s - %s", method.__name__, akwarglist, kw2)
#     347 additional_kwargs = self._get_s3_method_kwargs(method, *akwarglist, **kwargs)
# --> 348 return await _error_wrapper(
#     349     method, kwargs=additional_kwargs, retries=self.retries
#     350 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\s3fs\core.py:140, in _error_wrapper(func, args, kwargs, retries)
#     138         err = e
#     139 err = translate_boto_error(err)
# --> 140 raise err
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\s3fs\core.py:113, in _error_wrapper(func, args, kwargs, retries)
#     111 for i in range(retries):
#     112     try:
# --> 113         return await func(*args, **kwargs)
#     114     except S3_RETRYABLE_ERRORS as e:
#     115         err = e
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\aiobotocore\client.py:354, in AioBaseClient._make_api_call(self, operation_name, api_params)
#     352 else:
#     353     apply_request_checksum(request_dict)
# --> 354     http, parsed_response = await self._make_request(
#     355         operation_model, request_dict, request_context
#     356     )
#     358 await self.meta.events.emit(
#     359     'after-call.{service_id}.{operation_name}'.format(
#     360         service_id=service_id, operation_name=operation_name
#    (...)
#     365     context=request_context,
#     366 )
#     368 if http.status_code >= 300:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\aiobotocore\client.py:379, in AioBaseClient._make_request(self, operation_model, request_dict, request_context)
#     375 async def _make_request(
#     376     self, operation_model, request_dict, request_context
#     377 ):
#     378     try:
# --> 379         return await self._endpoint.make_request(
#     380             operation_model, request_dict
#     381         )
#     382     except Exception as e:
#     383         await self.meta.events.emit(
#     384             'after-call-error.{service_id}.{operation_name}'.format(
#     385                 service_id=self._service_model.service_id.hyphenize(),
#    (...)
#     389             context=request_context,
#     390         )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\aiobotocore\endpoint.py:96, in AioEndpoint._send_request(self, request_dict, operation_model)
#      94 context = request_dict['context']
#      95 self._update_retries_context(context, attempts)
# ---> 96 request = await self.create_request(request_dict, operation_model)
#      97 success_response, exception = await self._get_response(
#      98     request, operation_model, context
#      99 )
#     100 while await self._needs_retry(
#     101     attempts,
#     102     operation_model,
#    (...)
#     105     exception,
#     106 ):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\aiobotocore\endpoint.py:84, in AioEndpoint.create_request(self, params, operation_model)
#      80     service_id = operation_model.service_model.service_id.hyphenize()
#      81     event_name = 'request-created.{service_id}.{op_name}'.format(
#      82         service_id=service_id, op_name=operation_model.name
#      83     )
# ---> 84     await self._event_emitter.emit(
#      85         event_name,
#      86         request=request,
#      87         operation_name=operation_model.name,
#      88     )
#      89 prepared_request = self.prepare_request(request)
#      90 return prepared_request
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\aiobotocore\hooks.py:66, in AioHierarchicalEmitter._emit(self, event_name, kwargs, stop_on_response)
#      63 logger.debug('Event %s: calling handler %s', event_name, handler)
#      65 # Await the handler if its a coroutine.
# ---> 66 response = await resolve_awaitable(handler(**kwargs))
#      67 responses.append((handler, response))
#      68 if stop_on_response and response is not None:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\aiobotocore\_helpers.py:15, in resolve_awaitable(obj)
#      13 async def resolve_awaitable(obj):
#      14     if inspect.isawaitable(obj):
# ---> 15         return await obj
#      17     return obj
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\aiobotocore\signers.py:24, in AioRequestSigner.handler(self, operation_name, request, **kwargs)
#      19 async def handler(self, operation_name=None, request=None, **kwargs):
#      20     # This is typically hooked up to the "request-created" event
#      21     # from a client's event emitter.  When a new request is created
#      22     # this method is invoked to sign the request.
#      23     # Don't call this method directly.
# ---> 24     return await self.sign(operation_name, request)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\aiobotocore\signers.py:82, in AioRequestSigner.sign(self, operation_name, request, region_name, signing_type, expires_in, signing_name)
#      79     else:
#      80         raise e
# ---> 82 auth.add_auth(request)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\botocore\auth.py:418, in SigV4Auth.add_auth(self, request)
#     416 def add_auth(self, request):
#     417     if self.credentials is None:
# --> 418         raise NoCredentialsError()
#     419     datetime_now = datetime.datetime.utcnow()
#     420     request.context['timestamp'] = datetime_now.strftime(SIGV4_TIMESTAMP)
#
# NoCredentialsError: Unable to locate credentials
